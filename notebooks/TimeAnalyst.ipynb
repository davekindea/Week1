# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
data=pd.read_csv("./data/raw_analyst_ratings.csv")

# %%
data['publication_date'] = data['date'].str.split(' ').str[0]
data['publication_time'] = data['date'].str.split(' ').str[1]
data['publication_date'] = pd.to_datetime(data['publication_date'])
data['publication_hour'] = data['publication_time'].str[:2]


data.sort_values('date', inplace=True)

# %%
data
# Out:
#          Unnamed: 0                                           headline  \
# 879310       883755                       How Treasuries and ETFs Work
# 519806       522587      Update on the Luxury Sector: 2nd Quarter 2009
# 1390006     1396488      Update on the Luxury Sector: 2nd Quarter 2009
# 1432           1834                             Going Against the Herd
# 67712         68387  Charles Sizemore Radio Interview Saturday Morning
# ...             ...                                                ...
# 1039004     1044115  7 Stocks Moving In Thursday's After-Hours Session
# 1357564     1363985  Financials, Energy Among Worst-Hit Sectors In ...
# 1269090     1275136  Twitter Removes About 174,000 China-Linked Acc...
# 980443       985369  PG&E Corp Reports CPUC Approved Co.'s Microgri...
# 1343658     1350029                 Quicken Loans Plans To IPO: Report
#
#                                                        url  \
# 879310   https://www.benzinga.com/28044/how-treasuries-...
# 519806   https://www.benzinga.com/charles-lewis-sizemor...
# 1390006  https://www.benzinga.com/charles-lewis-sizemor...
# 1432     https://www.benzinga.com/charles-lewis-sizemor...
# 67712    https://www.benzinga.com/11218/charles-sizemor...
# ...                                                    ...
# 1039004  https://www.benzinga.com/news/20/06/16237924/7...
# 1357564  https://www.benzinga.com/news/20/06/16238109/f...
# 1269090  https://www.benzinga.com/tech/20/06/16238284/t...
# 980443   https://www.benzinga.com/news/20/06/16238398/p...
# 1343658  https://www.benzinga.com/news/20/06/16238300/q...
#
#                           publisher                       date stock  \
# 879310                 Paco Ahlgren        2009-02-14 00:00:00   NAV
# 519806   Charles Lewis Sizemore CFA        2009-04-27 00:00:00    FT
# 1390006  Charles Lewis Sizemore CFA        2009-04-27 00:00:00     Y
# 1432     Charles Lewis Sizemore CFA        2009-04-29 00:00:00     A
# 67712    Charles Lewis Sizemore CFA        2009-05-22 00:00:00    AM
# ...                             ...                        ...   ...
# 1039004                Tyree Gorges  2020-06-11 16:49:41-04:00   PVH
# 1357564                  JJ Kinahan  2020-06-11 16:51:33-04:00   WMT
# 1269090           Benzinga Newsdesk  2020-06-11 17:01:39-04:00  TWTR
# 980443            Benzinga Newsdesk  2020-06-11 17:11:20-04:00   PCG
# 1343658              Jason Shubnell  2020-06-11 17:12:35-04:00   WFC
#
#         publication_date publication_time publication_hour
# 879310        2009-02-14         00:00:00               00
# 519806        2009-04-27         00:00:00               00
# 1390006       2009-04-27         00:00:00               00
# 1432          2009-04-29         00:00:00               00
# 67712         2009-05-22         00:00:00               00
# ...                  ...              ...              ...
# 1039004       2020-06-11   16:49:41-04:00               16
# 1357564       2020-06-11   16:51:33-04:00               16
# 1269090       2020-06-11   17:01:39-04:00               17
# 980443        2020-06-11   17:11:20-04:00               17
# 1343658       2020-06-11   17:12:35-04:00               17
#
# [1407328 rows x 9 columns]

# %%
particular_day = data.groupby(data['publication_date'].dt.date).size()
particular_day.plot(kind='line')
plt.title('Number of Articles Published Over Time')
plt.xlabel('Date')
plt.ylabel('Number of Articles')
plt.show()

# %%
particular_year = data.groupby(data['publication_date'].dt.year).size()
particular_year.plot(kind='line')
plt.title('Number of Articles Published year')
plt.xlabel('Date')
plt.ylabel('Number of Articles')
plt.show()

# %%
particular_month = data.groupby(data['publication_date'].dt.month).size()
particular_month.plot(kind='line')
plt.title('Number of Articles Published ovet each month')
plt.xlabel('Date')
plt.ylabel('Number of Articles')
plt.show()

# %%
import matplotlib.pyplot as plt

# Group by 'publication_hour' and count the number of occurrences for each hour
hourly_counts = data.groupby('publication_hour').size()

# Plot the aggregated data
hourly_counts.plot(kind='line')
plt.title('Number of Articles Published Over Each Hour')
plt.xlabel('Hour')
plt.ylabel('Number of Articles')
plt.show()

# %%
data.head()
# Out:
#          Unnamed: 0                                           headline  \
# 879310       883755                       How Treasuries and ETFs Work
# 519806       522587      Update on the Luxury Sector: 2nd Quarter 2009
# 1390006     1396488      Update on the Luxury Sector: 2nd Quarter 2009
# 1432           1834                             Going Against the Herd
# 67712         68387  Charles Sizemore Radio Interview Saturday Morning
#
#                                                        url  \
# 879310   https://www.benzinga.com/28044/how-treasuries-...
# 519806   https://www.benzinga.com/charles-lewis-sizemor...
# 1390006  https://www.benzinga.com/charles-lewis-sizemor...
# 1432     https://www.benzinga.com/charles-lewis-sizemor...
# 67712    https://www.benzinga.com/11218/charles-sizemor...
#
#                           publisher                 date stock  \
# 879310                 Paco Ahlgren  2009-02-14 00:00:00   NAV
# 519806   Charles Lewis Sizemore CFA  2009-04-27 00:00:00    FT
# 1390006  Charles Lewis Sizemore CFA  2009-04-27 00:00:00     Y
# 1432     Charles Lewis Sizemore CFA  2009-04-29 00:00:00     A
# 67712    Charles Lewis Sizemore CFA  2009-05-22 00:00:00    AM
#
#         publication_date publication_time publication_hour
# 879310        2009-02-14         00:00:00               00
# 519806        2009-04-27         00:00:00               00
# 1390006       2009-04-27         00:00:00               00
# 1432          2009-04-29         00:00:00               00
# 67712         2009-05-22         00:00:00               00

# %%
data["stock"].value_counts()
# Out:
# stock
# MRK     3333
# MS      3238
# NVDA    3146
# MU      3142
# QQQ     3106
#         ...
# HTF        1
# TDI        1
# FAB        1
# QYLD       1
# VOOG       1
# Name: count, Length: 6204, dtype: int64
